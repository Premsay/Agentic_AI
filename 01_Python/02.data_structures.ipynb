# %% [markdown]
# # Data Structures
# Topics covered are:
# - [Lists](#Lists)
# - [Tuples](#tuples)
# - Sets
# - Dictionaries

# %% [markdown]
# ## Comparison of Core Data Structures
#
# | Data Structure | Syntax Example | Ordered? | Mutable? | Allows Duplicates? | Main Use Case |
# | :--- | :--- | :---: | :---: | :---: | :--- |
# | **List** | `['apple', 'banana']` | Yes | Yes | Yes | Flexible collections that can change |
# | **Tuple** | `('apple', 'banana')` | Yes | No | Yes | Fixed, read-only sequences |
# | **Dictionary** | `{'key': 'value'}` | Yes (since Python 3.7) | Yes | No (Keys) | Fast data lookup using keys |
# | **Set** | `{'apple', 'banana'}` | No | Yes | No | Removing duplicates and set operations |

# %% [markdown]
# ## Lists
# Lists are used to store multiple items in a single variable.

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)

#List items can be of any data type: String, int and boolean data types:
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]

#A list can contain different data types:
list1 = ["abc", 34, True, 40, "male"]
print(type(list1))
thislist = list(("apple", "banana", "cherry")) # note the double round-brackets
print(thislist)

# %%
#Access Items

# List items are indexed and you can access them by referring to the index number:
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[1])
print(thislist[-1]) #Negative indexing means start from the end
print(thislist[2:5]) #Range of Indexes
print(thislist[:4])  # This example returns the items from the beginning to, but NOT including, "kiwi"
print(thislist[-4:-1]) #Specify negative indexes if you want to start the search from the end of the list

if "apple" in thislist:
  print("Yes, 'apple' is in the fruits list")    #Check if "apple" is present in the list
# Out:
# banana
# mango
# ['cherry', 'orange', 'kiwi']
# ['apple', 'banana', 'cherry', 'orange']
# ['orange', 'kiwi', 'melon']
# Yes, 'apple' is in the fruits list

# %%
# Change Item Value
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1] = "pineapple"
print(thislist)    #Change the second item

thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)    # List is a mutuable data type so it can be changed in place

thislist[1:3] = ["muskmelon"]
print(thislist)   #Change the second and third value by replacing it with one value

thislist[1:2] = ["guava", "melon"]
print(thislist)   #Change the second value by replacing it with two new values
# Out:
# ['apple', 'pineapple', 'cherry', 'orange', 'kiwi', 'mango']
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']
# ['apple', 'muskmelon', 'orange', 'kiwi', 'mango']
# ['apple', 'guava', 'melon', 'orange', 'kiwi', 'mango']

# %%
#Insert Items

thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %%
#Append Items
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)

#Extend List
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)

#Add Any Iterable
thistuple = ("kiwi", "orange")
thislist.extend(thistuple)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry', 'orange', 'mango', 'pineapple', 'papaya']
# ['apple', 'banana', 'cherry', 'orange', 'mango', 'pineapple', 'papaya', 'kiwi', 'orange']

# %%
# Remove Specified Item
thislist = ["apple", "banana", "cherry","pineapple", "papaya"]
thislist.remove("banana")
print(thislist)

thislist.pop(1)  #Remove the second item
print(thislist)

thislist.pop()  #Remove the last item
print(thislist)

del thislist[0]  #Remove the first item
print(thislist)

thislist.clear()  #The clear() method empties the list.
print(thislist)

del thislist   #Delete the entire list:
# Out:
# ['apple', 'cherry', 'pineapple', 'papaya']
# ['apple', 'pineapple', 'papaya']
# ['apple', 'pineapple']
# ['pineapple']
# []

# %% [markdown]
# ## Loop Through a List

# %%
thislist = ["apple", "banana", "cherry"]
for x in thislist:
  print(x)

for i in range(len(thislist)):
  print(thislist[i])           #Use the range() and len() functions to create a suitable iterable.

i = 0
while i < len(thislist):
  print(thislist[i])      #Print all items, using a while loop to go through all the index numbers
  i = i + 1

[print(x) for x in thislist]  #A short hand for loop that will print all items in a list
# Out:
# apple
# banana
# cherry
# apple
# banana
# cherry
# apple
# banana
# cherry
# apple
# banana
# cherry
# [None, None, None]

# %% [markdown]
# ## TUPLES
